# %% [markdown]
# # Debug to Jupyter Export
#
# Variable: `df`

# %%
import joblib
df = joblib.load('/home/vnnot03353/.config/Code/User/globalStorage/sangnpq.debug-to-jupyter-rust/df.pkl')
print(f'Loaded {type(df).__name__}: {df}')
